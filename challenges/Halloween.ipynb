# %% [markdown]
# Copyright **`(c)`** 2023 Giovanni Squillero `<giovanni.squillero@polito.it>`
# [`https://github.com/squillero/computational-intelligence`](https://github.com/squillero/computational-intelligence)
# Free for personal or classroom use; see [`LICENSE.md`](https://github.com/squillero/computational-intelligence/blob/master/LICENSE.md) for details.

# %%
from itertools import product
from random import random, randint, shuffle, seed
import numpy as np
from scipy import sparse
from random import random, choice, randint
from functools import reduce
from collections import namedtuple
from copy import copy
from prettytable import PrettyTable
import time
import math

# %%
def make_set_covering_problem(num_points, num_sets, density):
    """Returns a sparse array where rows are sets and columns are the covered items"""
    seed(num_points*2654435761+num_sets+density)
    sets = np.array([
            [random() < density for i in range(num_points)]
            for j in range(num_sets)
        ])
    return sets

# %% [markdown]
# # Halloween Challenge
#
# Find the best solution with the fewest calls to the fitness functions for:
#
# * `num_points = [100, 1_000, 5_000]`
# * `num_sets = num_points`
# * `density = [.3, .7]`

# %%
NUM_POINTS = [100, 1000,5000]
NUM_SETS = NUM_POINTS
DENSITY = 0.3

# %%
def valid_points(sets, state):
    return  np.any(sets[state, :], axis=0).sum()

# %%
def is_valid(state,sets):
    return np.all(np.any(sets[state, :], axis=0))

# %%
def fitness1(sets, problem_size, state):
    def __name__():
        return 'fitness1'

    cost = sum(state)
    valid = valid_points(sets, state)
    return valid, -cost

def fitness2(sets, problem_size, state):
    def __name__():
        return 'fitness2'

    cost = sum(state)
    valid = np.all(np.any(sets[state, :], axis=0))
    return valid, -cost


def fitness3(sets, problem_size, state):
    def __name__():
        return 'fitness3'

    valid = valid_points(sets, state)
    return valid


def fitness4(sets, problem_size, state):
    def __name__():
        return 'fitness4'

    div=  5
    valid = math.floor(np.any(sets[state, :], axis=0).sum()/div)
    return valid

def fitness5(sets, problem_size, state):
    def __name__():
        return 'fitness5'

    cost = sum(state)
    total=sets.sum(axis=0)
    r=np.any(sets[state, :], axis=0)
    weighted=(r*(1/total))
    return weighted.sum(),-cost


def fitness6(sets, problem_size, state):
    def __name__():
        return 'fitness5'

    cost = sum(state)
    total=sets.sum(axis=0)
    r=np.any(sets[state, :], axis=0)
    weighted=(r*(1/total))
    return weighted.sum()

# %%
def tweak(problem_size, state, sets, method="stochastic"):
    new_state = copy(state)
    if method == "stochastic" :
        index = randint(0, problem_size - 1)
        new_state[index] = not new_state[index]
        return new_state
    elif method == "steepest_ascent" :
        best_state = None
        best_cost = -1
        for i in range(len(state)):
            new_state=copy(state)
            new_state[i] = not new_state[i]
            new_cost = valid_points(sets, new_state)
            if new_cost > best_cost:
                best_state = new_state
                best_cost = new_cost
        return best_state
    elif method == "first_choice" :
        for i in range(len(state)):
            if state[i]==False:
                new_state[i] = not new_state[i]
                return new_state
    return new_state

# %%
def hill_climbing(fitness,problem_size,current_state,sets,method):
    current_cost = fitness(sets,problem_size,current_state)
    count=0
    while True:
        new_state = tweak(problem_size,current_state,sets,method)
        new_cost = fitness(sets,problem_size,new_state)
        count+=1
        if new_cost >= current_cost:
            current_state = new_state
            current_cost = new_cost
        else:
            return current_state, current_cost, count

# %%
def restart_hill_climbing(fitness,problem_size,current_state,sets,method, max_iterations=100):
    count=0
    current_cost = fitness(sets,problem_size,current_state)
    while not is_valid(current_state,sets) and count < max_iterations:
        current_state, current_cost, current_count = hill_climbing(fitness,problem_size,current_state,sets,method)
        count+=current_count
    return current_state, current_cost, count

# %%
def iterated_local_search(fitness,problem_size,current_state,sets,method, max_iterations=100):
    count=0
    best_state=copy(current_state)
    best_cost = fitness(sets,problem_size,best_state)
    while not is_valid(best_state,sets) and count < max_iterations:
        new_state, new_cost, new_count = hill_climbing(fitness,problem_size,best_state,sets,method)
        count+=new_count
        if new_cost >= best_cost:
            best_state = new_state
            best_cost = new_cost
    return best_state, best_cost, count

# %%
def temp_schedule(T, iter, criteria="cauchy"):
    if criteria=="boltzmann":
        return T/(1+iter)
    elif criteria=="cauchy":
        return T/(1+math.log(iter))
    elif criteria=="exp":
        return T*math.exp(-iter)
    
def simulated_annealing(fitness,problem_size,initial_state,sets,method, max_iteration=100, p=None):
    T=problem_size/5
    count=0
    current_state=copy(initial_state)
    current_cost=fitness(sets,problem_size,current_state)
    while not is_valid(current_state,sets) and count<max_iteration:
        next_state=tweak(problem_size,current_state,sets,method)
        next_cost=fitness(sets,problem_size,next_state)
        count+=1
        error=next_cost-current_cost
        if p is None:
            if random()>=math.exp(-error/T):
                    current_state=next_state 
        else:
            if p>=math.exp(-error/T):
                current_state=next_state
        T=temp_schedule(T, count)
    return current_state, len(current_state), count

# %%
def compare(num_points, num_sets, density, fitness_functions, methods, variants):
    for i in range(len(num_points)):
        t = PrettyTable(["Points", "Sets", "Fitness Function", "Method","Variant","Count","Time","Cost","is_valid"])
        problem_size=num_points[i]
        set_num=num_sets[i]
        sets = make_set_covering_problem(problem_size, set_num, density)
        for fitness in fitness_functions:
            for method in methods:
                if method=="hill_climbing":
                    algorithm=hill_climbing
                elif method=="simulated_annealing":
                    algorithm=simulated_annealing
                elif method=="restart_hill_climbing":
                    algorithm=restart_hill_climbing
                elif method=="iterated_local_search":
                    algorithm=iterated_local_search
                for variant in variants:
                    start=time.time()
                    current_state=[False]*num_sets[i]
                    best_state, best_cost, count = algorithm(fitness,problem_size,current_state,sets,variant)
                    end=time.time()
                    t.add_row(
                            [
                                str(problem_size),
                                str(set_num),
                                str(fitness.__name__),
                                method,
                                variant,
                                str(count),
                                "{:.3e}".format(end - start),
                                str(best_cost),
                                is_valid(best_state,sets)
                            ]
                    )
        print(t)

# %%
compare(NUM_POINTS, NUM_SETS, DENSITY, fitness_functions=[fitness1, fitness5],methods=["hill_climbing","restart_hill_climbing","iterated_local_search"],variants=["stochastic","steepest_ascent","first_choice"])
# Out:
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# | Points | Sets | Fitness Function |         Method        |     Variant     | Count |    Time   |            Cost           | is_valid |
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# |  100   | 100  |     fitness1     |     hill_climbing     |    stochastic   |   11  | 6.852e-04 |         (99, -10)         |  False   |
# |  100   | 100  |     fitness1     |     hill_climbing     | steepest_ascent |   7   | 9.720e-03 |         (100, -6)         |   True   |
# |  100   | 100  |     fitness1     |     hill_climbing     |   first_choice  |   12  | 1.209e-04 |         (98, -11)         |  False   |
# |  100   | 100  |     fitness1     | restart_hill_climbing |    stochastic   |   15  | 2.041e-04 |         (100, -12)        |   True   |
# |  100   | 100  |     fitness1     | restart_hill_climbing | steepest_ascent |   7   | 5.310e-03 |         (100, -6)         |   True   |
# |  100   | 100  |     fitness1     | restart_hill_climbing |   first_choice  |  100  | 2.344e-03 |         (98, -11)         |  False   |
# |  100   | 100  |     fitness1     |  simulated_annealing  |    stochastic   |   20  | 3.982e-04 |            100            |   True   |
# |  100   | 100  |     fitness1     |  simulated_annealing  | steepest_ascent |   6   | 4.593e-03 |            100            |   True   |
# |  100   | 100  |     fitness1     |  simulated_annealing  |   first_choice  |   22  | 4.170e-04 |            100            |   True   |
# |  100   | 100  |     fitness1     | iterated_local_search |    stochastic   |   15  | 2.210e-04 |         (100, -9)         |   True   |
# |  100   | 100  |     fitness1     | iterated_local_search | steepest_ascent |   7   | 5.258e-03 |         (100, -6)         |   True   |
# |  100   | 100  |     fitness1     | iterated_local_search |   first_choice  |  100  | 2.382e-03 |         (98, -11)         |  False   |
# |  100   | 100  |     fitness5     |     hill_climbing     |    stochastic   |   11  | 2.759e-04 | (3.3880472024387345, -10) |  False   |
# |  100   | 100  |     fitness5     |     hill_climbing     | steepest_ascent |   7   | 5.752e-03 |  (3.4280472024387345, -6) |   True   |
# |  100   | 100  |     fitness5     |     hill_climbing     |   first_choice  |   12  | 2.751e-04 | (3.3445689415691695, -11) |  False   |
# |  100   | 100  |     fitness5     | restart_hill_climbing |    stochastic   |   17  | 5.469e-04 | (3.4280472024387345, -11) |   True   |
# |  100   | 100  |     fitness5     | restart_hill_climbing | steepest_ascent |   7   | 6.603e-03 |  (3.4280472024387345, -6) |   True   |
# |  100   | 100  |     fitness5     | restart_hill_climbing |   first_choice  |  100  | 4.941e-03 | (3.3445689415691695, -11) |  False   |
# |  100   | 100  |     fitness5     |  simulated_annealing  |    stochastic   |   20  | 3.908e-04 |            100            |   True   |
# |  100   | 100  |     fitness5     |  simulated_annealing  | steepest_ascent |   6   | 4.578e-03 |            100            |   True   |
# |  100   | 100  |     fitness5     |  simulated_annealing  |   first_choice  |   21  | 3.960e-04 |            100            |   True   |
# |  100   | 100  |     fitness5     | iterated_local_search |    stochastic   |   13  | 3.850e-04 | (3.4280472024387345, -10) |   True   |
# |  100   | 100  |     fitness5     | iterated_local_search | steepest_ascent |   7   | 6.817e-03 |  (3.4280472024387345, -6) |   True   |
# |  100   | 100  |     fitness5     | iterated_local_search |   first_choice  |  100  | 4.603e-03 | (3.3445689415691695, -11) |  False   |
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# | Points | Sets | Fitness Function |         Method        |     Variant     | Count |    Time   |            Cost           | is_valid |
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# |  1000  | 1000 |     fitness1     |     hill_climbing     |    stochastic   |   16  | 8.302e-04 |        (1000, -15)        |   True   |
# |  1000  | 1000 |     fitness1     |     hill_climbing     | steepest_ascent |   11  | 4.194e-01 |        (1000, -10)        |   True   |
# |  1000  | 1000 |     fitness1     |     hill_climbing     |   first_choice  |   16  | 7.451e-04 |         (995, -15)        |  False   |
# |  1000  | 1000 |     fitness1     | restart_hill_climbing |    stochastic   |   25  | 1.712e-03 |        (1000, -19)        |   True   |
# |  1000  | 1000 |     fitness1     | restart_hill_climbing | steepest_ascent |   11  | 4.247e-01 |        (1000, -10)        |   True   |
# |  1000  | 1000 |     fitness1     | restart_hill_climbing |   first_choice  |  100  | 1.219e-02 |         (995, -15)        |  False   |
# |  1000  | 1000 |     fitness1     |  simulated_annealing  |    stochastic   |   21  | 1.827e-03 |            1000           |   True   |
# |  1000  | 1000 |     fitness1     |  simulated_annealing  | steepest_ascent |   11  | 4.290e-01 |            1000           |   True   |
# |  1000  | 1000 |     fitness1     |  simulated_annealing  |   first_choice  |   22  | 1.779e-03 |            1000           |   True   |
# |  1000  | 1000 |     fitness1     | iterated_local_search |    stochastic   |   18  | 1.108e-03 |        (1000, -15)        |   True   |
# |  1000  | 1000 |     fitness1     | iterated_local_search | steepest_ascent |   11  | 4.243e-01 |        (1000, -10)        |   True   |
# |  1000  | 1000 |     fitness1     | iterated_local_search |   first_choice  |  100  | 1.154e-02 |         (995, -15)        |  False   |
# |  1000  | 1000 |     fitness5     |     hill_climbing     |    stochastic   |   19  | 1.583e-02 |  (3.340860129501899, -18) |   True   |
# |  1000  | 1000 |     fitness5     |     hill_climbing     | steepest_ascent |   11  | 4.414e-01 |  (3.340860129501899, -10) |   True   |
# |  1000  | 1000 |     fitness5     |     hill_climbing     |   first_choice  |   16  | 1.491e-02 | (3.3237135144508323, -15) |  False   |
# |  1000  | 1000 |     fitness5     | restart_hill_climbing |    stochastic   |   27  | 3.151e-02 |  (3.340860129501899, -18) |   True   |
# |  1000  | 1000 |     fitness5     | restart_hill_climbing | steepest_ascent |   11  | 4.253e-01 |  (3.340860129501899, -10) |   True   |
# |  1000  | 1000 |     fitness5     | restart_hill_climbing |   first_choice  |  100  | 1.561e-01 | (3.3237135144508323, -15) |  False   |
# |  1000  | 1000 |     fitness5     |  simulated_annealing  |    stochastic   |   26  | 2.140e-03 |            1000           |   True   |
# |  1000  | 1000 |     fitness5     |  simulated_annealing  | steepest_ascent |   10  | 3.763e-01 |            1000           |   True   |
# |  1000  | 1000 |     fitness5     |  simulated_annealing  |   first_choice  |   23  | 1.876e-03 |            1000           |   True   |
# |  1000  | 1000 |     fitness5     | iterated_local_search |    stochastic   |   20  | 1.748e-02 |  (3.340860129501899, -19) |   True   |
# |  1000  | 1000 |     fitness5     | iterated_local_search | steepest_ascent |   11  | 4.250e-01 |  (3.340860129501899, -10) |   True   |
# |  1000  | 1000 |     fitness5     | iterated_local_search |   first_choice  |  100  | 1.543e-01 | (3.3237135144508323, -15) |  False   |
# +--------+------+------------------+-----------------------+-----------------+-------+-----------+---------------------------+----------+
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> compare(NUM_POINTS, NUM_SETS, DENSITY, fitness_functions=[fitness1, fitness5],methods=["hill_climbing","restart_hill_climbing","simulated_annealing","iterated_local_search"],variants=["stochastic","steepest_ascent","first_choice"])
#
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a> start=time.time()
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a> current_state=[False]*num_sets[i]
# ---> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=19'>20</a> best_state, best_cost, count = algorithm(fitness,problem_size,current_state,sets,variant)
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=20'>21</a> end=time.time()
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=21'>22</a> t.add_row(
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=22'>23</a>         [
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=23'>24</a>             str(problem_size),
#    (...)
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=32'>33</a>         ]
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=33'>34</a> )
#
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> current_cost = fitness(sets,problem_size,current_state)
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> while not is_valid(current_state,sets) and count < max_iterations:
# ----> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     current_state, current_cost, current_count = hill_climbing(fitness,problem_size,current_state,sets,method)
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     count+=current_count
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> return current_state, current_cost, count
#
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 5
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> count=0
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> while True:
# ----> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>     new_state = tweak(problem_size,current_state,sets,method)
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a>     new_cost = fitness(sets,problem_size,new_state)
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a>     count+=1
#
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 1
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a> new_state=copy(state)
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a> new_state[i] = not new_state[i]
# ---> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a> new_cost = valid_points(sets, new_state)
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=13'>14</a> if new_cost > best_cost:
#      <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=14'>15</a>     best_state = new_state
#
# /Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb Cell 15 line 2
#       <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> def valid_points(sets, state):
# ----> <a href='vscode-notebook-cell:/Users/manuelescobar/Documents/POLITO/2023-2/CI/Computational-Intelligence/challenges/Halloween.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a>     return  np.any(sets[state, :], axis=0).sum()
#
# KeyboardInterrupt:

# %%
compare(NUM_POINTS, NUM_SETS, DENSITY, fitness_functions=[fitness3, fitness6],methods=["simulated_annealing"],variants=["stochastic","steepest_ascent","first_choice"])
